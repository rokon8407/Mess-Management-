# %%
def insert_student(student_id, name, mobile, address, deposit):
    with open('MessData.txt', 'a') as f:
        f.write(f"{student_id},{name},{mobile},{address},{deposit},0\n")

def update_meals(student_id, meals):
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    updated_data = []
    for line in data:
        if line.startswith(student_id):
            parts = line.strip().split(',')
            parts[5] = str(int(parts[5]) + meals)
            updated_data.append(','.join(parts) + '\n')
        else:
            updated_data.append(line)

    with open('MessData.txt', 'w') as f:
        f.writelines(updated_data)

def check_balance(student_id):
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    for line in data:
        if line.startswith(student_id):
            parts = line.strip().split(',')
            return float(parts[4])

    return None

def update_balance(student_id, amount):
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    updated_data = []
    for line in data:
        if line.startswith(student_id):
            parts = line.strip().split(',')
            parts[4] = str(float(parts[4]) + amount)
            updated_data.append(','.join(parts) + '\n')
        else:
            updated_data.append(line)

    with open('MessData.txt', 'w') as f:
        f.writelines(updated_data)

def get_meals_count(student_id):
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    for line in data:
        if line.startswith(student_id):
            parts = line.strip().split(',')
            return int(parts[5])

    return None

def get_student_status(student_id):
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    for line in data:
        if line.startswith(student_id):
            parts = line.strip().split(',')
            return {
                "ID": parts[0],
                "Name": parts[1],
                "Mobile": parts[2],
                "Address": parts[3],
                "Balance": parts[4],
                "Meals": parts[5]
            }

    return None

def display_all_students():
    with open('MessData.txt', 'r') as f:
        data = f.readlines()

    for line in data:
        parts = line.strip().split(',')
        print(f"ID:{parts[0]}, Name: {parts[1]}, Mobile: {parts[2]}, Address: {parts[3]}, Deposit: {parts[4]}, Meals: {parts[5]}")

def main():
    print("Welcome to Abdullah Chatrabash Mess Management System")

    while True:
        print("\nOptions:")
        print("1. Add new student")
        print("2. Update meals for a student")
        print("3. Check balance")
        print("4. Check meals count")
        print("5. Get student status")
        print("6. Display all students")
        print("7. Update balance for a student")
        print("0. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            student_id = input("Enter student ID: ")
            name = input("Enter student name: ")
            mobile = input("Enter mobile number: ")
            address = input("Enter address (city): ")
            deposit = input("Enter initial deposit amount: ")
            insert_student(student_id, name, mobile, address, deposit)
            print(f"Student added successfully! Student ID: {student_id}")

        elif choice == '2':
            student_id = input("Enter student ID: ")
            meals = int(input("Enter number of meals to add: "))
            update_meals(student_id, meals)
            print("Meals updated successfully!")

        elif choice == '3':
            student_id = input("Enter student ID: ")
            balance = check_balance(student_id)
            if balance is not None:
                print(f"Current balance for student {student_id}: {balance}")
            else:
                print("Student not found.")

        elif choice == '4':
            student_id = input("Enter student ID: ")
            meals = get_meals_count(student_id)
            if meals is not None:
                print(f"Total meals for student {student_id} this month: {meals}")
            else:
                print("Student not found.")

        elif choice == '5':
            student_id = input("Enter student ID: ")
            status = get_student_status(student_id)
            if status:
                print("Student Status:")
                for key, value in status.items():
                    print(f"{key}: {value}")
            else:
                print("Student not found.")

        elif choice == '6':
            display_all_students()

        elif choice == '7':
            student_id = input("Enter student ID: ")
            amount = float(input("Enter amount to add (use negative for deduction): "))
            update_balance(student_id, amount)
            print("Balance updated successfully!")

        elif choice == '0':
            print("Thank you for using Abdullah Chatrabash Mess Management System. Goodbye!")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to Abdullah Chatrabash Mess Management System
#
# Options:
# 1. Add new student
# 2. Update meals for a student
# 3. Check balance
# 4. Check meals count
# 5. Get student status
# 6. Display all students
# 7. Update balance for a student
# 0. Exit
# Enter your choice:  6
# ID:AC1, Name: Rokon, Mobile: 01796078879, Address: Rangpur, Deposit: 1500.0, Meals: 15
# ID:AC2, Name: Kamal, Mobile: 01796548788, Address: Dinajpur, Deposit: 1500, Meals: 5
# ID:AC3, Name: Zia, Mobile: 0164857455, Address: Dinajpur, Deposit: 1200, Meals: 7
# ID:AC4, Name: Minhaj, Mobile: 01796854778, Address: Barishal, Deposit: 1455, Meals: 8
# ID:AC5, Name: Zamal, Mobile: 01786376637, Address: Dhaka, Deposit: 1700, Meals: 5
# ID:AC6, Name: Mehedi, Mobile: 01786548755, Address: Khulna, Deposit: 1100, Meals: 6
# ID:AC7, Name: Asif, Mobile: 01987654321, Address: Chittagong, Deposit: 1250, Meals: 7
# ID:AC8, Name: Rifat, Mobile: 01897531234, Address: Sylhet, Deposit: 1350, Meals: 8
# ID:AC9, Name: Nazmul, Mobile: 01786321987, Address: Dhaka, Deposit: 1500, Meals: 10
# ID:AC10, Name: Shamim, Mobile: 01987623145, Address: Rajshahi, Deposit: 2100.0, Meals: 10
# ID:AC11, Name: Arif, Mobile: 01875432198, Address: Rangpur, Deposit: 2200.0, Meals: 11
# ID:AC12, Name: Saiful, Mobile: 01785321465, Address: Barishal, Deposit: 1900.0, Meals: 13
# ID:AC13, Name: Nazim, Mobile: 01896453217, Address: Chittagong, Deposit: 2000.0, Meals: 14
# ID:AC14, Name: Farhan, Mobile: 01987625314, Address: Sylhet, Deposit: 2100.0, Meals: 15
# ID:AC15, Name: Karim, Mobile: 01785321465, Address: Comilla, Deposit: 1600.0, Meals: 11
# ID:AC16, Name: Fahim, Mobile: 01896425314, Address: Dhaka, Deposit: 1700.0, Meals: 12
# ID:AC17, Name: Rafid, Mobile: 01786532148, Address: Rajshahi, Deposit: 1800.0, Meals: 13
# ID:AC18, Name: Sumon, Mobile: 01986425317, Address: Khulna, Deposit: 2000.0, Meals: 15
# ID:AC19, Name: Imran, Mobile: 01785321476, Address: Barishal, Deposit: 2100.0, Meals: 10
# ID:AC20, Name: Salman, Mobile: 01897521345, Address: Rangpur, Deposit: 1400, Meals: 9
# ID:AC21, Name: Hasan, Mobile: 01986543217, Address: Dhaka, Deposit: 1300, Meals: 7
# ID:AC22, Name: Mahfuz, Mobile: 01798653241, Address: Khulna, Deposit: 1450, Meals: 8
# ID:AC23, Name: Firoz, Mobile: 01897543128, Address: Rajshahi, Deposit: 1550, Meals: 9
# ID:AC24, Name: Rashid, Mobile: 01987625431, Address: Sylhet, Deposit: 1650, Meals: 10
# ID:AC25, Name: Tanvir, Mobile: 01786543218, Address: Comilla, Deposit: 1750, Meals: 6
# ID:AC26, Name: Shahid, Mobile: 01789654321, Address: Khulna, Deposit: 1150, Meals: 7
# ID:AC27, Name: Imtiaz, Mobile: 01896543212, Address: Chittagong, Deposit: 1250, Meals: 8
# ID:AC28, Name: Nasir, Mobile: 01987654312, Address: Dhaka, Deposit: 1350, Meals: 9
# ID:AC29, Name: Sajib, Mobile: 01786542143, Address: Sylhet, Deposit: 1450, Meals: 10
# ID:AC30, Name: Jahid, Mobile: 01896543214, Address: Barishal, Deposit: 1550, Meals: 6
#
# Options:
# 1. Add new student
# 2. Update meals for a student
# 3. Check balance
# 4. Check meals count
# 5. Get student status
# 6. Display all students
# 7. Update balance for a student
# 0. Exit
